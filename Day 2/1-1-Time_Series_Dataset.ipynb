# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
from pandas import read_csv
import matplotlib.pyplot as plt
dataset = read_csv('/content/drive/My Drive/Deep Learning with Python/Day 2/dataset/international-airline-passengers.csv', 
                   usecols=[1], engine='python', skipfooter=3)

# %%
plt.plot(dataset)
plt.show()

# %%
print(dataset)
